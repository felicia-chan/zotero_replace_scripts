# %% [markdown]
# ## Task
# * find and replace the string values in "extra" column with accession number only

# %%
import pandas as pd
import re

# %%
csv_files = ["export-data (1).csv", 
             "export-data (2).csv", 
             "export-data (3).csv", 
             "export-data (4).csv", 
             "export-data (5).csv"]

zotero = pd.DataFrame()

# appends all files together, zotero only allowed batch exports of size 100
for file in csv_files:
            df_temp = pd.read_csv(file)
            zotero = zotero.append(df_temp, ignore_index=True)

zotero.head()
# Out:
#         Key       Item Type  Publication Year                       Author  \
# 0  6HKRDSPR  journalArticle              2020                Pozo Buil, M.
# 1  7FKS5CFF  journalArticle              2020                Bourne, H. L.
# 2  AL55MRHI  journalArticle              2020                 Amaya, D. J.
# 3  ZF6V3DS5          thesis              2020  Coale, T. H.; Allen, Andrew
# 4  MLCHZBMI  journalArticle              2019              Whitmore, B. M.
#
#                                                Title  \
# 0  An Ensemble view of the Decadal Predictability...
# 1  Carbon Export and Fate Beneath a Dynamic Upwel...
# 2  Are long-term changes in mixed layer depth inf...
# 3  Characterizing the influence of iron on the ce...
# 4  A comparison between Zooglider and shipboard n...
#
#                                  Publication Title ISBN  ISSN  DOI  \
# 0                               Journal of Climate  NaN   NaN  NaN
# 1                           Biogeosciences Discuss  NaN   NaN  NaN
# 2  Bulletin of the American Meteorological Society  NaN   NaN  NaN
# 3                                              NaN  NaN   NaN  NaN
# 4                     Journal of Plankton Research  NaN   NaN  NaN
#
#                                                  Url  ...  \
# 0                                                NaN  ...
# 1  https://urldefense.com/v3/__https://doi.org/10...  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#   Programming Language Version System Code  Code Number Section  Session  \
# 0                  NaN     NaN    NaN  NaN          NaN     NaN      NaN
# 1                  NaN     NaN    NaN  NaN          NaN     NaN      NaN
# 2                  NaN     NaN    NaN  NaN          NaN     NaN      NaN
# 3                  NaN     NaN    NaN  NaN          NaN     NaN      NaN
# 4                  NaN     NaN    NaN  NaN          NaN     NaN      NaN
#
#   Committee History  Legislative Body
# 0       NaN     NaN               NaN
# 1       NaN     NaN               NaN
# 2       NaN     NaN               NaN
# 3       NaN     NaN               NaN
# 4       NaN     NaN               NaN
#
# [5 rows x 87 columns]

# %%
def find_num(string):
    if type(string) != str:
        return string
    splitted = string.split() # split string into individual words
    result = [i for i in splitted if i.startswith("#")] # get only the string that starts with #
    return re.sub('\D', '', result[0])

# %%
zotero['Extra'] = zotero['Extra'].apply(find_num)

# %%
zotero.to_csv("updated_zotero.csv", sep=",", index=False)

# %%
zotero['Extra']
# Out:
# 0      0419
# 1      0491
# 2      0478
# 3      0490
# 4      0455
#        ...
# 493    0030
# 494    0016
# 495    0012
# 496    0007
# 497    0011
# Name: Extra, Length: 498, dtype: object
